# %%
import pandas as pd
delays_df = pd.read_csv('Data/flight_data.csv')
delays_df[['DISTANCE', 'CRS_ELAPSED_TIME', 'ARR_DELAY']]
# Out:
#         DISTANCE  CRS_ELAPSED_TIME  ARR_DELAY
# 0           1670               225      -17.0
# 1           1670               225      -25.0
# 2            580               105      -13.0
# 3            580               105      -12.0
# 4            580               100       -7.0
# ...          ...               ...        ...
# 299995       386                87       -7.0
# 299996       386                92      -13.0
# 299997       221                71       -2.0
# 299998       221                81      -13.0
# 299999       240                66        6.0
#
# [300000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x = delays_df.loc[:,['DISTANCE', 'CRS_ELAPSED_TIME']]
y = delays_df.loc[:,['ARR_DELAY']]
x_training, x_test, y_training, y_test = train_test_split(x, y, test_size=0.3, random_state=123)
